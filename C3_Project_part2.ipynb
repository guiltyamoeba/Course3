# %%
import random

def word_guessing_game():

    word_list = ["apple", "banana", "orange", "grape", "kiwi", "mango", "pear", "strawberry", "watermelon"]
    secret_word = random.choice(word_list)
    word_length = len(secret_word)
    guess_count = 0
    max_guesses = 6

    print("Welcome to the Word Guessing Game!")

    while guess_count < max_guesses:
        guess = input("Guess a word: ").lower()

        if guess == secret_word:
            print("Congratulations! You guessed the word!")
            break
        else:
            guess_count += 1
            print(f"Incorrect. You have {max_guesses - guess_count} guesses left.")

            if guess_count == 3:
                print("Hint: The word has", word_length, "letters.")

    if guess_count == max_guesses:
        print(f"Sorry, you ran out of guesses. The word was {secret_word}.")

if __name__ == "__main__":
    word_guessing_game()

# %%
#task2
import random

def arithmetic_puzzle():
    """
    Plays an arithmetic puzzle game.

    Returns:
        int: The player's score.
    """

    score = 0
    total_questions = 0

    while True:
        num1 = random.randint(1, 10)
        num2 = random.randint(1, 10)
        operator = random.choice(['+', '-', '*', '/'])

        # Handle division by zero
        while num2 == 0 and operator == '/':
            num2 = random.randint(1, 10)

        print(f"What is {num1} {operator} {num2}?")

        try:
            user_answer = float(input("Your answer: "))

            if operator == '+':
                correct_answer = num1 + num2
            elif operator == '-':
                correct_answer = num1 - num2
            elif operator == '*':
                correct_answer = num1 * num2
            else:
                correct_answer = num1 / num2

            total_questions += 1
            if abs(user_answer - correct_answer) < 0.001:
                print("Correct!")
                score += 1
            else:
                print(f"Incorrect. The answer is: {correct_answer}")

        except ValueError:
            print("Invalid input. Please enter a number.")

        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != "yes":
            break

    if total_questions > 0:
        percentage = (score / total_questions) * 100
        print(f"Your final score is: {percentage:.2f}%")
    else:
        print("You didn't answer any questions.")

    return score

def riddle_game():
    """
    Plays a riddle game.

    Returns:
        int: The player's score.
    """

    riddles = {
        "What has an eye but cannot see?": "A needle",
        "I have cities, but no houses; I have mountains, but no trees; I have water, but no fish; I have roads, but no cars. What am I?": "A map",
        "What can run but never walks, has a mouth but never talks, has a bed but never sleeps?": "A river",
        "I have keys but no locks, space but no room. You can enter, but can't go inside. What am I?": "A keyboard"
    }

    score = 0
    total_questions = 0

    while True:
        riddle, answer = random.choice(list(riddles.items()))
        print(riddle)

        user_answer = input("Your answer: ").lower()

        total_questions += 1
        if user_answer == answer.lower():
            print("Correct!")
            score += 1
        else:
            print("Incorrect. The answer is:", answer)

        play_again = input("Do you want to play again? (yes/no): ").lower()
        if play_again != "yes":
            break

    if total_questions > 0:
        percentage = (score / total_questions) * 100
        print(f"Your final score is: {percentage:.2f}%")
    else:
        print("You didn't answer any questions.")

    return score

def general_knowledge_quiz():
    """
    Plays a general knowledge quiz game.

    Returns:
        int: The player's score.
    """

    questions = [
        {"question": "Which gas do plants absorb during photosynthesis?", "answer": "Carbon dioxide"},
        {"question": "What is the full name of the WWW?", "answer": "World Wide Web"},
        {"question": "How many bones are there in the adult human body?", "answer": "206"}
    ]

    score = 0
    total_questions = len(questions)

    for question in questions:
        print(question["question"])
        user_answer = input("Your answer: ").lower()

        if user_answer == question["answer"].lower():
            print("Correct!")
            score += 1
        else:
            print("Incorrect. The answer is:", question["answer"])

    percentage = (score / total_questions) * 100
    print(f"Your final score is: {percentage:.2f}%")

    return score

def rock_paper_scissors_user():
    """
    Plays a rock, paper, scissors game against the user.

    Returns:
        int: The player's score (1 for win, 0 for loss or tie).
    """

    options = ["rock", "paper", "scissors"]

    while True:
        computer_choice = random.choice(options)
        user_choice = input("Rock, Paper, or Scissors? ").lower()

        if user_choice not in options:
            print("Invalid input. Please choose Rock, Paper, or Scissors.")
            continue

        print(f"Computer chose: {computer_choice}")

        if user_choice == computer_choice:
            print("It's a tie!")
            score = 0
        elif user_choice == "rock":
            if computer_choice == "scissors":
                print("You win! Rock smashes scissors.")
                score = 1
            else:
                print("You lose! Paper covers rock.")
                score = 0
        elif user_choice == "paper":
            if computer_choice == "rock":
                print("You win! Paper covers rock.")
                score = 1
            else:
                print("You lose! Scissors cuts paper.")
                score = 0
        elif user_choice == "scissors":
            if computer_choice == "paper":
                print("You win! Scissors cuts paper.")
                score = 1
            else:
                print("You lose! Rock smashes scissors.")
                score = 0

        play_again = input("Play again? (yes/no): ").lower()
        if play_again != "yes":
            break

    return score

def word_guessing_game():
    """
    Plays a word guessing game.

    Returns:
        int: The player's score (1 for win, 0 for loss).
    """

    words = ["python", "coding", "employee", "company", "success", "challenge", "teamwork"]
    secret_word = random.choice(words)
    word_length = len(secret_word)
    guesses = []
    max_attempts = 6

    print("Welcome to the Word Guessing Game!")
    print("Guess the secret word.")

    # Optional clue: number of letters
    print("Hint: The word has", word_length, "letters.")

    while len(guesses) < max_attempts:
        guess = input("Enter your guess: ").lower()

        if guess in guesses:
            print("You already guessed that.")
            continue

        guesses.append(guess)

        if guess == secret_word:
            print("Congratulations, you guessed the word!")
            score = 1
            break

        if guess not in secret_word:
            print("Incorrect guess.")

    else:
        print("Sorry, you ran out of attempts. The word was:", secret_word)
        score = 0

    return score

def main():
    """
    Main function that displays the menu and handles game selection.

    Returns:
        None
    """

    games = {
        "1": arithmetic_puzzle,
        "2": riddle_game,
        "3": general_knowledge_quiz,
        "4": rock_paper_scissors_user,
        "5": word_guessing_game
    }

    while True:
        print("\nSelect what you want to play from Menu:\n")
        print("1. Arithmetic Puzzle Game")
        print("2. Riddle Puzzle Game")
        print("3. General Knowledge Quiz Game")
        print("4. Rock Paper Scissors Game")
        print("5. Word Guessing Game")
        print("6. Exit \n")
        choice = input("Choose an option (1-6): ").strip()

        if choice == "6":
            play_again = input("Do you want to play again? (yes/no): ").strip().lower()
            if play_again != "yes":
                print("Thank you for playing. See you next time. Exiting the program.")
                break
        elif choice in games:
            score = games[choice]()  # Call the game function and store the score
            print(f"Your score: {score}")
        else:
            print("You have entered wrong option. Please select a number between 1 and 5.")

if __name__ == "__main__":
    main()
# Out:
# Select what you want to play from Menu:
#
# 1. Arithmetic Puzzle Game
# 2. Riddle Puzzle Game
# 3. General Knowledge Quiz Game
# 4. Rock Paper Scissors Game
# 5. Word Guessing Game
# 6. Exit
